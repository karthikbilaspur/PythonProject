# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
df=sns.load_dataset("iris")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='r', label='Iris setosa')
plt.scatter(X[y == 2, 0], X[y == 2, 1], c='b', label='Iris virginica')
plt.scatter(X[y == 1, 0], X[y == 1, 1], c='g', label='Iris versicolor')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Length vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs Sepal Width')

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target_names[iris.target]


sns.pairplot(iris_df, hue='species', diag_kind='hist')

# %%
sns.boxplot(x='species', y='petal length (cm)', data=iris_df)
plt.title('Box Plot of Petal Length by Species')
# Out:
# Text(0.5, 1.0, 'Box Plot of Petal Length by Species')

# %%
sns.countplot(x='species', data=iris_df)
plt.title('Species Counts in Iris Dataset')
# Out:
# Text(0.5, 1.0, 'Species Counts in Iris Dataset')

# %%
sns.barplot(x='species', y='petal length (cm)', data=iris_df, errorbar=None)
plt.title('Mean Petal Length by Species')
plt.figure(figsize=(10, 6))

# %%
g = sns.PairGrid(iris_df, hue='species')
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot, kde_kws={'color': 'k'})
g.map_lower(sns.kdeplot, cmap='Blues_d')
# Out:
# e:\PythonProject\.venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# e:\PythonProject\.venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# e:\PythonProject\.venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# e:\PythonProject\.venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# e:\PythonProject\.venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# e:\PythonProject\.venv\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
# ...

# %%
sns.violinplot(x='species', y='petal length (cm)', hue='species', data=iris_df)
plt.title('Blue Plot of Petal Length by Species and Sepal Width')
# Out:
# Text(0.5, 1.0, 'Blue Plot of Petal Length by Species and Sepal Width')
